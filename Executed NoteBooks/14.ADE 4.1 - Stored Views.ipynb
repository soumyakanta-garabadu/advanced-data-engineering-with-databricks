# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Stored Views
#
# In this notebook, we'll give a quick overview of how stored views are created and managed. Recall that stored views differ from DataFrames and temp views by persisting to a database (allowing other users to leverage pre-defined logic to materialize results). Views register the logic required to calculate a result (which will be evaluated when the query is executed). Views defined against Delta Lake sources are guaranteed to always query the latest version of each data source.
#
# The goal of this notebook is to generate a view that allows the analysts from our partner gyms to examine how use of Moovio devices and workouts impact gym activity.
#
# <img src="https://files.training.databricks.com/images/ade/ADE_arch_gym_report.png" width="60%" />
#
# ## Learning Objectives
# By the end of this lesson, students will be able to:
# - Display the query plan associated with a view
# - Describe how results are materialized from Delta Lake tables

# %% [markdown]
# ## Setup

# %%
# %run ../Includes/Classroom-Setup-5.1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Creating the database &#34;dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1&#34;
# Creating bronze...(4 seconds / 10,841,978 records)
# Creating user_lookup...(3 seconds / 100 records)
# Creating gym_mac_logs...(3 seconds / 314 records)
#
# Processing the workouts_silver table...(14 seconds / 1,514 records)
# Processing the completed_workouts table...(3 seconds / 757 records)
#
# Predefined Paths:
#   DA.paths.working_dir: dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1
#   DA.paths.user_db:     dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/5_1.db
#   DA.paths.checkpoints: dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/_checkpoints
#
# Predefined tables in dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1:
#   bronze
#   completed_workouts
#   gym_mac_logs
#   user_lookup
#   workouts_silver
#
# Validating datasets...(1 seconds)
#
# Setup completed in 29 seconds
# </div>

# %% [markdown]
# ## Examine Gym Logs
#
# Start by reviewing the schema for your gym logs.

# %%
gymDF = spark.table("gym_mac_logs")
gymDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- first_timestamp: double (nullable = true)
# -- gym: long (nullable = true)
# -- last_timestamp: double (nullable = true)
# -- mac: string (nullable = true)
#
# </div>

# %% [markdown]
# A Spark DataFrame and a view are nearly identical constructs. By calling **`explain`** on our DataFrame, we can see that our source table is a set of instructions to deserialize the files containing our data.

# %%
gymDF.explain("formatted")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# * ColumnarToRow (2)
# +- Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.gym_mac_logs (1)
#
#
# (1) Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.gym_mac_logs
# Output [4]: [first_timestamp#40691, gym#40692L, last_timestamp#40693, mac#40694]
# Batched: true
# Location: PreparedDeltaFileIndex [dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/5_1.db/gym_mac_logs]
# ReadSchema: struct&lt;first_timestamp:double,gym:bigint,last_timestamp:double,mac:string&gt;
#
# (2) ColumnarToRow [codegen id : 1]
# Input [4]: [first_timestamp#40691, gym#40692L, last_timestamp#40693, mac#40694]
#
#
# </div>

# %% [markdown]
# ## Examine Workout Data
#
# Rather than trying to capture every possible metric in our view, we'll create a summary of values that might be of interest to our gym analysts.
#
# The data we're receiving from our gyms indicates the first and last timestamp recorded for user devices, indicated by mac address.

# %%
# %sql
SELECT * FROM gym_mac_logs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first
# %% [markdown]
# ## Expand on the Query
#
# Now we'll join this data back to the MAC logs sent by the gym to create our view.
#
# We'll retain the **`mac_address`** as our identifier, which we can grab from the **`user_lookup`** table.
#
# We'll also add columns to calculate the total number of minutes elapsed during a user's visit to the gym, as well as the total number of minutes elapsed between the beginning of their first workout and the end of their final workout.

# %%
# %sql
SELECT gym, mac_address, date, workouts, (last_timestamp - first_timestamp)/60 minutes_in_gym, (to_unix_timestamp(end_workout) - to_unix_timestamp(start_workout))/60 minutes_exercising
FROM gym_mac_logs c
INNER JOIN (
  SELECT b.mac_address, to_date(start_time) date, collect_set(workout_id) workouts, min(start_time) start_workout, max(end_time) end_workout
      FROM completed_workouts a
      INNER JOIN user_lookup b
      ON a.user_id = b.user_id
      GROUP BY mac_address, to_date(start_time)
  ) d
  ON c.mac = d.mac_address AND to_date(CAST(c.first_timestamp AS timestamp)) = d.date
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gym</th><th>mac_address</th><th>date</th><th>workouts</th><th>minutes_in_gym</th><th>minutes_exercising</th></tr></thead><tbody><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-01</td><td>List(49, 43)</td><td>49.75</td><td>40.53333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-02</td><td>List(21, 22)</td><td>97.66666666666667</td><td>91.73333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-03</td><td>List(24, 21)</td><td>47.1</td><td>38.4</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-04</td><td>List(27)</td><td>57.46666666666667</td><td>46.93333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-05</td><td>List(31, 21)</td><td>84.91666666666667</td><td>68.26666666666667</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-07</td><td>List(2, 7)</td><td>94.45</td><td>78.93333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-08</td><td>List(39, 41)</td><td>56.63333333333333</td><td>46.93333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-09</td><td>List(38, 36)</td><td>125.31666666666666</td><td>110.93333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-10</td><td>List(23)</td><td>69.05</td><td>66.13333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-11</td><td>List(9)</td><td>60.43333333333333</td><td>42.666666666666664</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-12</td><td>List(15, 23)</td><td>127.21666666666667</td><td>115.2</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-14</td><td>List(34, 20)</td><td>75.51666666666667</td><td>59.733333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-15</td><td>List(2)</td><td>45.666666666666664</td><td>36.266666666666666</td></tr><tr><td>6</td><td>08:24:96:7a:28:d6</td><td>2019-12-16</td><td>List(15)</td><td>51.25</td><td>46.93333333333333</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-04</td><td>List(32)</td><td>72.58333333333333</td><td>66.13333333333334</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-08</td><td>List(13, 23)</td><td>140.11666666666667</td><td>121.6</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-09</td><td>List(27, 29)</td><td>95.65</td><td>89.6</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-10</td><td>List(25)</td><td>70.3</td><td>57.6</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-11</td><td>List(8)</td><td>79.9</td><td>70.4</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-15</td><td>List(2, 18)</td><td>65.08333333333333</td><td>46.93333333333333</td></tr><tr><td>4</td><td>09:d1:bf:ec:2e:ec</td><td>2019-12-16</td><td>List(36)</td><td>73.93333333333334</td><td>61.86666666666667</td></tr><tr><td>4</td><td>14:89:99:7f:53:9c</td><td>2019-12-02</td><td>List(15)</td><td>66.08333333333333</td><td>53.333333333333336</td></tr><tr><td>4</td><td>14:89:99:7f:53:9c</td><td>2019-12-09</td><td>List(43, 25)</td><td>120.71666666666667</td><td>102.4</td></tr><tr><td>6</td><td>14:cd:d6:db:70:f6</td><td>2019-12-10</td><td>List(38)</td><td>70.26666666666667</td><td>55.46666666666667</td></tr><tr><td>6</td><td>14:cd:d6:db:70:f6</td><td>2019-12-13</td><td>List(22)</td><td>77.16666666666667</td><td>68.26666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-02</td><td>List(46)</td><td>82.46666666666667</td><td>74.66666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-03</td><td>List(17, 29)</td><td>99.65</td><td>85.33333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-04</td><td>List(3)</td><td>43.65</td><td>29.866666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-05</td><td>List(20, 39)</td><td>51.9</td><td>46.93333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-06</ ...

# %% [markdown]
# ## Register View with Final Logic
#
# Create a (non-temporary) view called **`gym_user_stats`** using the query above.
#
# **`CREATE VIEW IF NOT EXISTS gym_user_stats AS (...)`**

# %%
# %sql
-- TODO
CREATE VIEW IF NOT EXISTS gym_user_stats AS
(
SELECT gym, mac_address, date, workouts, (last_timestamp - first_timestamp)/60 minutes_in_gym, (to_unix_timestamp(end_workout) - to_unix_timestamp(start_workout))/60 minutes_exercising
FROM gym_mac_logs c
INNER JOIN (
  SELECT b.mac_address, to_date(start_time) date, collect_set(workout_id) workouts, min(start_time) start_workout, max(end_time) end_workout
      FROM completed_workouts a
      INNER JOIN user_lookup b
      ON a.user_id = b.user_id
      GROUP BY mac_address, to_date(start_time)
  ) d
  ON c.mac = d.mac_address AND to_date(CAST(c.first_timestamp AS timestamp)) = d.date)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# Check your work
assert spark.sql("SHOW TABLES").filter("tableName='gym_user_stats'").count() >= 1, "View 'gym_user_stats' does not exist."
assert spark.sql("SHOW TABLES").filter("tableName='gym_user_stats'").first()["isTemporary"]==False, "View 'gym_user_stats' should be not temporary."
assert spark.sql("DESCRIBE EXTENDED gym_user_stats").filter("col_name='Type'").first()['data_type']=='VIEW', "Found a table 'gym_user_stats' when a view was expected."
assert spark.table("gym_user_stats").count() == 304, "Incorrect query used for view 'gym_user_stats'."
print("All tests passed.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">All tests passed.
# </div>

# %% [markdown]
# We can see that our view is simply storing the Spark plan for our query.

# %%
spark.table("gym_user_stats").explain("formatted")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# AdaptiveSparkPlan (16)
# +- Project (15)
#    +- BroadcastHashJoin Inner BuildLeft (14)
#       :- BroadcastExchange (3)
#       :  +- Filter (2)
#       :     +- Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.gym_mac_logs (1)
#       +- ObjectHashAggregate (13)
#          +- Exchange (12)
#             +- ObjectHashAggregate (11)
#                +- Project (10)
#                   +- BroadcastHashJoin Inner BuildRight (9)
#                      :- Filter (5)
#                      :  +- Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.completed_workouts (4)
#                      +- BroadcastExchange (8)
#                         +- Filter (7)
#                            +- Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.user_lookup (6)
#
#
# (1) Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.gym_mac_logs
# Output [4]: [first_timestamp#41309, gym#41310L, last_timestamp#41311, mac#41312]
# Batched: true
# Location: PreparedDeltaFileIndex [dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/5_1.db/gym_mac_logs]
# PushedFilters: [IsNotNull(mac), IsNotNull(first_timestamp)]
# ReadSchema: struct&lt;first_timestamp:double,gym:bigint,last_timestamp:double,mac:string&gt;
#
# (2) Filter
# Input [4]: [first_timestamp#41309, gym#41310L, last_timestamp#41311, mac#41312]
# Condition : (isnotnull(mac#41312) AND isnotnull(first_timestamp#41309))
#
# (3) BroadcastExchange
# Input [4]: [first_timestamp#41309, gym#41310L, last_timestamp#41311, mac#41312]
# Arguments: HashedRelationBroadcastMode(ArrayBuffer(input[3, string, false], cast(cast(input[0, double, false] as timestamp) as date)),false), [id=#30793]
#
# (4) Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.completed_workouts
# Output [4]: [user_id#41313, workout_id#41314, start_time#41316, end_time#41317]
# Batched: true
# Location: PreparedDeltaFileIndex [dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/5_1.db/completed_workouts]
# PushedFilters: [IsNotNull(user_id)]
# ReadSchema: struct&lt;user_id:int,workout_id:int,start_time:timestamp,end_time:timestamp&gt;
#
# (5) Filter
# Input [4]: [user_id#41313, workout_id#41314, start_time#41316, end_time#41317]
# Condition : (isnotnull(user_id#41313) AND isnotnull(cast(start_time#41316 as date)))
#
# (6) Scan parquet dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1.user_lookup
# Output [2]: [mac_address#41321, user_id#41322L]
# Batched: true
# Location: PreparedDeltaFileIndex [dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1/5_1.db/user_lookup]
# PushedFilters: [IsNotNull(user_id), IsNotNull(mac_address)]
# ReadSchema: struct&lt;mac_address:string,user_id:bigint&gt;
#
# (7) Filter
# Input [2]: [mac_address#41321, user_id#41322L]
# Condition : (isnotnull(user_id#41322L) AND isnotnull(mac_address#41321))
#
# (8) BroadcastExchange
# Input [2]: [mac_address#41321, user_id#41322L]
# Arguments: HashedRelationBroadcastMode(List(input[1, bigint, false]),false), [id=#30785]
#
# (9) BroadcastHashJoin
# Left keys [1]: [cast(user_id#41313 as bigint)]
# Right keys [1]: [user_id#41322L]
# Join condition: None
#
# (10) Project
# Output [5]: [workout_id#41314, start_time#41316, end_time#41317, mac_address#41321, cast(start_time#41316 as date) AS _groupingexpression#41335]
# Input [6]: [user_id#41313, workout_id#41314, start_time#41316, end_time#41317, mac_address#41321, user_id#41322L]
#
# (11) ObjectHashAggregate
# Input [5]: [workout_id#41314, start_time#41316, end_time#41317, mac_address#41321, _groupingexpression#41335]
# Keys [2]: [mac_address#41321, _groupingexpression#41335]
# Functions [3]: [partial_collect_set(workout_id#41314, 0, 0) AS buf#41337, partial_min(start_time#41316) AS min#41339, partial_max(end_time#41317) AS max#41341]
# Aggregate Attributes [3]: [buf#41336, min#41338, max#41340]
# Results [5]: [mac_address#41321, _groupingexpression#41335, buf#41337, min#41339, max#41341]
#
# (12) Exchange
# Input [5]: [mac_address#41321, _groupingexpression#41335, buf#41337, min#41339, max#41341]
# Arguments: hashpartitioning(mac_address#41321, _groupingexpression#41335, 4), ENSURE_REQUIREMENTS, [id=#30790]
#
# (13) ObjectHashAggregate
# Input [5]: [mac_address#41321, _groupingexpression#41335, buf#41337, min#41339, max#41341]
# Keys [2]: [mac_address#41321, _groupingexpression#41335]
# Functions [3]: [finalmerge_collect_set(merge buf#41337) AS collect_set(workout_id#41314, 0, 0)#41325, finalmerge_min(merge min#41339) AS min(start_time#41316)#41326, finalmerge_max(merge max#41341) AS max(end_time#41317)#41327]
# Aggregate Attributes [3]: [collect_set(workout_id#41314, 0, 0)#41325, min(start_time#41316)#41326, max(end_time#41317)#41327]
# Results [5]: [mac_address#41321, _groupingexpression#41335 AS date#41283, collect_set(workout_id#41314, 0, 0)#41325 AS workouts#41284, min(start_time#41316)#41326 AS start_workout#41285, max(end_time#41317)#41327 AS end_workout#41286]
#
# (14) BroadcastHashJoin
# Left keys [2]: [mac#41312, cast(cast(first_timestamp#41309 as timestamp) as date)]
# Right keys [2]: [mac_address#41321, date#41283]
# Join condition: None
#
# (15) Project
# Output [6]: [gym#41310L, mac_address#41321, date#41283, workouts#41284, ((last_timestamp#41311 - first_timestamp#41309) / 60.0) AS minutes_in_gym#41293, (cast((to_unix_timestamp(end_workout#41286, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), false) - to_unix_timestamp(start_workout#41285, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), false)) as double) / 60.0) AS minutes_exercising#41294]
# Input [9]: [first_timestamp#41309, gym#41310L, last_timestamp#41311, mac#41312, mac_address#41321, date#41283, workouts#41284, start_workout#41285, end_workout#41286]
#
# (16) AdaptiveSparkPlan
# Output [6]: [gym#41310L, mac_address#41321, date#41283, workouts#41284, minutes_in_gym#41293, minutes_exercising#41294]
# Arguments: isFinalPlan=false
#
#
# </div>

# %% [markdown]
# When we execute a query against this view, we will process the plan to generate the logically correct result.
#
# Note that while the data may end up in the Delta Cache, this result is not guaranteed to be persisted, and is only cached for the currently active cluster.

# %%
# %sql
SELECT *
FROM gym_user_stats
WHERE gym = 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gym</th><th>mac_address</th><th>date</th><th>workouts</th><th>minutes_in_gym</th><th>minutes_exercising</th></tr></thead><tbody><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-01</td><td>List(49, 43)</td><td>49.75</td><td>40.53333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-02</td><td>List(21, 22)</td><td>97.66666666666667</td><td>91.73333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-03</td><td>List(24, 21)</td><td>47.1</td><td>38.4</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-04</td><td>List(27)</td><td>57.46666666666667</td><td>46.93333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-05</td><td>List(31, 21)</td><td>84.91666666666667</td><td>68.26666666666667</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-07</td><td>List(2, 7)</td><td>94.45</td><td>78.93333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-08</td><td>List(39, 41)</td><td>56.63333333333333</td><td>46.93333333333333</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-09</td><td>List(38, 36)</td><td>125.31666666666666</td><td>110.93333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-10</td><td>List(23)</td><td>69.05</td><td>66.13333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-11</td><td>List(9)</td><td>60.43333333333333</td><td>42.666666666666664</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-12</td><td>List(15, 23)</td><td>127.21666666666667</td><td>115.2</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-14</td><td>List(34, 20)</td><td>75.51666666666667</td><td>59.733333333333334</td></tr><tr><td>5</td><td>00:6c:6c:53:51:ef</td><td>2019-12-15</td><td>List(2)</td><td>45.666666666666664</td><td>36.266666666666666</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-02</td><td>List(46)</td><td>82.46666666666667</td><td>74.66666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-03</td><td>List(17, 29)</td><td>99.65</td><td>85.33333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-04</td><td>List(3)</td><td>43.65</td><td>29.866666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-05</td><td>List(20, 39)</td><td>51.9</td><td>46.93333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-06</td><td>List(0, 1)</td><td>96.58333333333333</td><td>85.33333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-07</td><td>List(23)</td><td>77.58333333333333</td><td>66.13333333333334</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-08</td><td>List(1, 40)</td><td>98.46666666666667</td><td>85.33333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-09</td><td>List(48, 45)</td><td>74.58333333333333</td><td>64.0</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-10</td><td>List(46)</td><td>85.65</td><td>74.66666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-11</td><td>List(3, 26)</td><td>110.81666666666666</td><td>91.73333333333333</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-12</td><td>List(25)</td><td>66.2</td><td>55.46666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-13</td><td>List(19)</td><td>92.38333333333334</td><td>78.93333333333334</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-14</td><td>List(15)</td><td>73.71666666666667</td><td>61.86666666666667</td></tr><tr><td>5</td><td>1b:55:35:cb:d8:22</td><td>2019-12-15</td><td>List(42, 29)</td><td>104.11666666666666</td><td>89.6</td></tr><tr><td>5</td><td>1d:f9:5b:33:df:2d</td><td>2019-12-15</td><td>List(49, 6)</td><td>66.45</td><td>59.733333333333334</td></tr><tr><td>5</td><td>35:d1:c5:f0:79:75</td><td>2019-12-07</td><td>List(35)</td><td>68.95</td><td>59.733333333333334</td></tr><tr><td>5</t ...

# %% [markdown]
# ## An Aside on ACLs
#
# While Databricks has extensive support for ACLs, by default these are not enforced for standard data engineering clusters. As such, the default permissions for this view are set to all users, and no owner has been declared.

# %%
import py4j

try:
    spark.sql("SHOW GRANT ON VIEW gym_user_stats")
    
except py4j.protocol.Py4JJavaError as e:
    print("Error: " + e.java_exception.getMessage())
    print("Solution: Consider enabling Table Access Control to demonstrate this feature.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Error: Trying to perform permission action on Hive Metastore /CATALOG/`hive_metastore`/DATABASE/`dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1`/TABLE/`gym_user_stats` but Table Access Control is not enabled on this cluster.
# Solution: Consider enabling Table Access Control to demonstrate this feature.
# </div>

# %% [markdown]
# While the privileges for this view may not be especially sensitive, we can see that our bronze table (which contains ALL our raw data) is also currently stored in this fashion.
#
# Again, ACLs are primarily intended for managing data access within the Databricks workspace for BI and data science use cases. For sensitive data engineering data, you will want to make sure that you limit access to the storage containers using your cloud identity management.

# %%
try:
    spark.sql("SHOW GRANT ON TABLE bronze")
    
except py4j.protocol.Py4JJavaError as e:
    print("Error: " + e.java_exception.getMessage())
    print("Solution: Consider enabling Table Access Control to demonstrate this feature.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Error: Trying to perform permission action on Hive Metastore /CATALOG/`hive_metastore`/DATABASE/`dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1`/TABLE/`bronze` but Table Access Control is not enabled on this cluster.
# Solution: Consider enabling Table Access Control to demonstrate this feature.
# </div>

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %%
DA.cleanup()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dropping the database &#34;dbacademy_odl_user_771624_databrickslabs_com_adewd_5_1&#34;
# Removing the working directory &#34;dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.1&#34;
# Validating datasets...(0 seconds)
# </div>

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
