# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Materialized Gold Tables
#
# Because the lakehouse combines on-demand compute resources with infinitely scalable cloud object storage to optimize cost and performance, the concept of a materialized view most closely maps to that of a gold table. Rather than caching the results to the view for quick access, results are stored in Delta Lake for efficient deserialization.
#
# **NOTE**: Databricks SQL leverages <a href="https://docs.databricks.com/sql/admin/query-caching.html#query-caching" target="_blank">Delta caching and query caching</a>, so subsequent execution of queries will use cached results.
#
# Gold tables refer to highly refined, generally aggregate views of the data persisted to Delta Lake.
#
# These tables are intended to drive core business logic, dashboards, and applications.
#
# The necessity of gold tables will evolve over time; as more analysts and data scientists use your Lakehouse, analyzing query history will reveal trends in how data is queried, when, and by whom. Collaborating across teams, data engineers and platform admins can define SLAs to make highly valuable data available to teams in a timely fashion, all while cutting down the potential costs and latency associated with larger ad hoc queries.
#
# In this notebook, we'll create a gold table that stores summary statistics about each completed workout alongside binned demographic information. In this way, our application can quickly populate statistics about how other users performed on the same workouts.
#
# <img src="https://files.training.databricks.com/images/ade/ADE_arch_bpm_summary.png" width="60%" />
#
# ## Learning Objectives
# By the end of this lesson, students will be able to:
# - Describe performance differences between views and tables
# - Implement a streaming aggregate table

# %% [markdown]
# ## Setup
# Set up path and checkpoint variables (these will be used later).

# %%
# %run ../Includes/Classroom-Setup-5.2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Creating the database &#34;dbacademy_odl_user_771624_databrickslabs_com_adewd_5_2&#34;
# Creating bronze...(4 seconds / 10,841,978 records)
# Creating user_lookup...(3 seconds / 100 records)
# Creating gym_mac_logs...(3 seconds / 314 records)
#
# Processing the heart_rate_silver table...(42 seconds / 9,034,893 records)
# Processing the workouts_silver table...(9 seconds / 1,514 records)
# Processing the completed_workouts table...(3 seconds / 757 records)
# Processing the workout_bpm table...(9 seconds / 197,201 records)
# Processing the users table...(10 seconds)
# ...delete_requests: 6 records)
# ...users: 100 records)
# Processing user_bins table...(3 seconds / 100 records)
#
# Predefined Paths:
#   DA.paths.working_dir: dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.2
#   DA.paths.user_db:     dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.2/5_2.db
#   DA.paths.checkpoints: dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.2/_checkpoints
#
# Predefined tables in dbacademy_odl_user_771624_databrickslabs_com_adewd_5_2:
#   bronze
#   completed_workouts
#   delete_requests
#   gym_mac_logs
#   heart_rate_silver
#   user_bins
#   user_lookup
#   users
#   workout_bpm
#   workouts_silver
#
# Validating datasets...(1 seconds)
#
# Setup completed in 89 seconds
# </div>

# %% [markdown]
# ## Explore Workout BPM
# Recall that our **`workout_bpm`** table has already matched all completed workouts to user bpm recordings.
#
# Explore this data below.

# %%
# %sql
SELECT * 
FROM workout_bpm
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>workout_id</th><th>session_id</th><th>time</th><th>heartrate</th></tr></thead><tbody><tr><td>36117</td><td>5</td><td>314</td><td>2019-12-02T07:10:51.000+0000</td><td>125.26368756909095</td></tr><tr><td>36117</td><td>5</td><td>314</td><td>2019-12-02T07:16:20.000+0000</td><td>147.90040295844068</td></tr><tr><td>36117</td><td>5</td><td>314</td><td>2019-12-02T07:26:51.000+0000</td><td>139.2137133879535</td></tr><tr><td>36117</td><td>5</td><td>314</td><td>2019-12-02T07:35:44.000+0000</td><td>88.29318327972032</td></tr><tr><td>38766</td><td>30</td><td>402</td><td>2019-12-02T07:36:41.000+0000</td><td>97.20195580865813</td></tr><tr><td>12474</td><td>45</td><td>3</td><td>2019-12-02T07:40:08.000+0000</td><td>107.04813156326179</td></tr><tr><td>14232</td><td>32</td><td>474</td><td>2019-12-02T07:53:32.000+0000</td><td>144.145340797465</td></tr><tr><td>38766</td><td>30</td><td>402</td><td>2019-12-02T07:55:24.000+0000</td><td>108.71960338500051</td></tr><tr><td>38766</td><td>30</td><td>402</td><td>2019-12-02T08:00:52.000+0000</td><td>108.38694796645322</td></tr><tr><td>12474</td><td>45</td><td>3</td><td>2019-12-02T08:01:25.000+0000</td><td>63.47976032714755</td></tr></tbody></table></div>

# %% [markdown]
# Here we calculate some summary statistics for our workouts.

# %%
# %sql
SELECT user_id, workout_id, session_id, MIN(heartrate) min_bpm, MEAN(heartrate) avg_bpm, MAX(heartrate) max_bpm, COUNT(heartrate) num_recordings
FROM workout_bpm
GROUP BY user_id, workout_id, session_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>workout_id</th><th>session_id</th><th>min_bpm</th><th>avg_bpm</th><th>max_bpm</th><th>num_recordings</th></tr></thead><tbody><tr><td>12474</td><td>45</td><td>3</td><td>57.11846349626094</td><td>92.34721283552929</td><td>123.77188205079553</td><td>230</td></tr><tr><td>14508</td><td>47</td><td>393</td><td>58.22173113661009</td><td>93.50938540279812</td><td>113.49901140031896</td><td>193</td></tr><tr><td>16093</td><td>42</td><td>493</td><td>71.08167055818177</td><td>110.39402171061992</td><td>166.27147951549387</td><td>320</td></tr><tr><td>28588</td><td>21</td><td>2</td><td>81.74440849450012</td><td>112.60388589497185</td><td>160.06707482451796</td><td>128</td></tr><tr><td>24863</td><td>43</td><td>1</td><td>55.728371077283605</td><td>93.67163937906587</td><td>113.11578195451335</td><td>141</td></tr><tr><td>42387</td><td>8</td><td>1</td><td>60.63179276381176</td><td>98.3072480126614</td><td>139.26758708521538</td><td>449</td></tr><tr><td>24863</td><td>47</td><td>2</td><td>55.675317173446096</td><td>92.41404290112807</td><td>105.55667704065402</td><td>166</td></tr><tr><td>35728</td><td>31</td><td>405</td><td>54.25373956280828</td><td>111.9039894644047</td><td>147.23271728707257</td><td>282</td></tr><tr><td>27306</td><td>47</td><td>163</td><td>68.31222099481197</td><td>108.15629046356788</td><td>127.72139717731947</td><td>179</td></tr><tr><td>33987</td><td>35</td><td>487</td><td>70.5887871847356</td><td>93.42879200506445</td><td>130.70680703681953</td><td>346</td></tr><tr><td>37012</td><td>1</td><td>56</td><td>51.21193883454026</td><td>76.10179850421733</td><td>113.42256961244996</td><td>409</td></tr><tr><td>27306</td><td>47</td><td>164</td><td>66.77313163909159</td><td>108.99421596715484</td><td>129.33548438472442</td><td>179</td></tr><tr><td>35226</td><td>21</td><td>404</td><td>68.19206601196396</td><td>94.68368007468857</td><td>132.27360808619457</td><td>128</td></tr><tr><td>34740</td><td>15</td><td>313</td><td>82.79264332381273</td><td>117.67973437257177</td><td>155.0833613226391</td><td>281</td></tr><tr><td>34740</td><td>35</td><td>314</td><td>80.98634762268104</td><td>106.88624315456178</td><td>149.3970598666999</td><td>398</td></tr><tr><td>30088</td><td>23</td><td>447</td><td>57.047998940334296</td><td>117.78043742246362</td><td>160.4261239123373</td><td>385</td></tr><tr><td>29213</td><td>31</td><td>299</td><td>54.328208549709224</td><td>83.13921437171606</td><td>118.8699541873684</td><td>282</td></tr><tr><td>14232</td><td>48</td><td>476</td><td>79.92777972193412</td><td>125.4495609573218</td><td>157.14098775640034</td><td>141</td></tr><tr><td>34740</td><td>17</td><td>316</td><td>82.4789391771963</td><td>124.04212041584152</td><td>166.7193914376837</td><td>321</td></tr><tr><td>45875</td><td>31</td><td>213</td><td>58.50906441376472</td><td>92.94769283137869</td><td>125.31754178797131</td><td>282</td></tr><tr><td>40872</td><td>5</td><td>80</td><td>78.28795118024229</td><td>105.03441738280942</td><td>162.50973821309097</td><td>243</td></tr><tr><td>28521</td><td>12</td><td>329</td><td>50.65873551719189</td><td>77.7533455633603</td><td>106.34409473330135</td><td>141</td></tr><tr><td>24018</td><td>32</td><td>151</td><td>66.12220864226441</td><td>101.34833610171313</td><td>137.8095173305455</td><td>384</td></tr><tr><td>28588</td><td>36</td><td>4</td><td>78.0149839832272</td><td>125.00111525847558</td><td>162.43253257242486</td><td>320</td></tr><tr><td>23916</td><td>8</td><td>1</td><td>53.05916031155896</td><td>81.77513260018775</td><td>114.47770806817297</td><td>487</td></tr><tr><td>35728</td><td>19</td><td>410</td><td>49.398742549684684</td><td>114.94837656779531</td><td>142.6512408486474</td><td>679</td></tr><tr><td>25477</td><td>49</td><td>1</td><td>69.97006288917022</td><td>104.56032574189184</td><td>129.697924919263</td><td>77</td></tr><tr><td>47356</td><td>35</td><td>4</td><td>77.24404915654699 ...

# %% [markdown]
# And now we can use our **`user_lookup`** table to match this back to our binned demographic information.

# %%
# %sql
SELECT workout_id, session_id, a.user_id, age, gender, city, state, min_bpm, avg_bpm, max_bpm, num_recordings
FROM user_bins a
INNER JOIN 
  (SELECT user_id, workout_id, session_id, 
          min(heartrate) AS min_bpm, 
          mean(heartrate) AS avg_bpm,
          max(heartrate) AS max_bpm, 
          count(heartrate) AS num_recordings
   FROM workout_bpm
   GROUP BY user_id, workout_id, session_id) b
ON a.user_id = b.user_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>workout_id</th><th>session_id</th><th>user_id</th><th>age</th><th>gender</th><th>city</th><th>state</th><th>min_bpm</th><th>avg_bpm</th><th>max_bpm</th><th>num_recordings</th></tr></thead><tbody><tr><td>45</td><td>3</td><td>12474</td><td>75-85</td><td>M</td><td>San Fernando</td><td>CA</td><td>57.11846349626094</td><td>92.34721283552929</td><td>123.77188205079553</td><td>230</td></tr><tr><td>47</td><td>393</td><td>14508</td><td>85-95</td><td>M</td><td>Sierra Madre</td><td>CA</td><td>58.22173113661009</td><td>93.50938540279812</td><td>113.49901140031896</td><td>193</td></tr><tr><td>42</td><td>493</td><td>16093</td><td>35-45</td><td>F</td><td>Northridge</td><td>CA</td><td>71.08167055818177</td><td>110.39402171061992</td><td>166.27147951549387</td><td>320</td></tr><tr><td>21</td><td>2</td><td>28588</td><td>35-45</td><td>M</td><td>Arcadia</td><td>CA</td><td>81.74440849450012</td><td>112.60388589497185</td><td>160.06707482451796</td><td>128</td></tr><tr><td>43</td><td>1</td><td>24863</td><td>85-95</td><td>M</td><td>Long Beach</td><td>CA</td><td>55.728371077283605</td><td>93.67163937906587</td><td>113.11578195451335</td><td>141</td></tr><tr><td>8</td><td>1</td><td>42387</td><td>55-65</td><td>F</td><td>Playa Vista</td><td>CA</td><td>60.63179276381176</td><td>98.3072480126614</td><td>139.26758708521538</td><td>449</td></tr><tr><td>47</td><td>2</td><td>24863</td><td>85-95</td><td>M</td><td>Long Beach</td><td>CA</td><td>55.675317173446096</td><td>92.41404290112807</td><td>105.55667704065402</td><td>166</td></tr><tr><td>31</td><td>405</td><td>35728</td><td>55-65</td><td>F</td><td>Montebello</td><td>CA</td><td>54.25373956280828</td><td>111.9039894644047</td><td>147.23271728707257</td><td>282</td></tr><tr><td>47</td><td>163</td><td>27306</td><td>55-65</td><td>F</td><td>Edwards</td><td>CA</td><td>68.31222099481197</td><td>108.15629046356788</td><td>127.72139717731947</td><td>179</td></tr><tr><td>35</td><td>487</td><td>33987</td><td>55-65</td><td>F</td><td>Canyon Country</td><td>CA</td><td>70.5887871847356</td><td>93.42879200506445</td><td>130.70680703681953</td><td>346</td></tr><tr><td>1</td><td>56</td><td>37012</td><td>95+</td><td>M</td><td>Torrance</td><td>CA</td><td>51.21193883454026</td><td>76.10179850421733</td><td>113.42256961244996</td><td>409</td></tr><tr><td>47</td><td>164</td><td>27306</td><td>55-65</td><td>F</td><td>Edwards</td><td>CA</td><td>66.77313163909159</td><td>108.99421596715484</td><td>129.33548438472442</td><td>179</td></tr><tr><td>21</td><td>404</td><td>35226</td><td>65-75</td><td>M</td><td>Glendale</td><td>CA</td><td>68.19206601196396</td><td>94.68368007468857</td><td>132.27360808619457</td><td>128</td></tr><tr><td>15</td><td>313</td><td>34740</td><td>25-35</td><td>M</td><td>Santa Monica</td><td>CA</td><td>82.79264332381273</td><td>117.67973437257177</td><td>155.0833613226391</td><td>281</td></tr><tr><td>35</td><td>314</td><td>34740</td><td>25-35</td><td>M</td><td>Santa Monica</td><td>CA</td><td>80.98634762268104</td><td>106.88624315456178</td><td>149.3970598666999</td><td>398</td></tr><tr><td>23</td><td>447</td><td>30088</td><td>25-35</td><td>M</td><td>Los Angeles</td><td>CA</td><td>57.047998940334296</td><td>117.78043742246362</td><td>160.4261239123373</td><td>385</td></tr><tr><td>31</td><td>299</td><td>29213</td><td>95+</td><td>F</td><td>North Hollywood</td><td>CA</td><td>54.328208549709224</td><td>83.13921437171606</td><td>118.8699541873684</td><td>282</td></tr><tr><td>48</td><td>476</td><td>14232</td><td>35-45</td><td>M</td><td>North Hollywood</td><td>CA</td><td>79.92777972193412</td><td>125.4495609573218</td><td>157.14098775640034</td><td>141</td></tr><tr><td>17</td><td>316</td><td>34740</td><td>25-35</td><td>M</td><td>Santa Monica</td><td>CA</td><td>82.4789391771963</td><td>124.04212041584152</td><td>166.7193914376837</td><td>321</td></tr><tr><td>31</td><td>213</td><td>45875</td><td>85-95</td><t ...

# %% [markdown]
# ## Perform an Incremental Batch Table Update
# Because our **`workout_bpm`** table was written as an append-only stream, we can update our aggregation using a streaming job as well.

# %%
(spark.readStream
      .table("workout_bpm")
      .createOrReplaceTempView("TEMP_workout_bpm"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Using trigger-available-now logic with Delta Lake, we can ensure that we'll only calculate new results if records have changed in the upstream source tables.

# %%
user_bins_df = spark.sql("""
    SELECT workout_id, session_id, a.user_id, age, gender, city, state, min_bpm, avg_bpm, max_bpm, num_recordings
    FROM user_bins a
    INNER JOIN
      (SELECT user_id, workout_id, session_id, 
              min(heartrate) AS min_bpm, 
              mean(heartrate) AS avg_bpm, 
              max(heartrate) AS max_bpm, 
              count(heartrate) AS num_recordings
       FROM TEMP_workout_bpm
       GROUP BY user_id, workout_id, session_id) b
    ON a.user_id = b.user_id
    """)

(user_bins_df
     .writeStream
     .format("delta")
     .option("checkpointLocation", f"{DA.paths.checkpoints}/workout_bpm_summary")
     .option("path", f"{DA.paths.user_db}/workout_bpm_summary.delta")
     .outputMode("complete")
     .trigger(availableNow=True)
     .table("workout_bpm_summary")
     .awaitTermination())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Query Results
#
# Note that the primary benefit to scheduling updates to gold tables as opposed to defining views is the ability to control costs associated with materializing results.
#
# While returning results from this table will use some compute to scan the **`workout_bpm_summary`** table, this design avoids having to scan and join files from multiple tables every time this data is referenced.

# %%
# %sql
SELECT * FROM workout_bpm_summary
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>workout_id</th><th>session_id</th><th>user_id</th><th>age</th><th>gender</th><th>city</th><th>state</th><th>min_bpm</th><th>avg_bpm</th><th>max_bpm</th><th>num_recordings</th></tr></thead><tbody><tr><td>3</td><td>83</td><td>26285</td><td>45-55</td><td>M</td><td>Beverly Hills</td><td>CA</td><td>37.05482849444279</td><td>113.23867744062687</td><td>133.54441348291</td><td>166</td></tr><tr><td>3</td><td>416</td><td>14508</td><td>85-95</td><td>M</td><td>Sierra Madre</td><td>CA</td><td>64.15209715278007</td><td>93.99203734055368</td><td>117.71193587065262</td><td>154</td></tr><tr><td>40</td><td>486</td><td>36164</td><td>85-95</td><td>F</td><td>Carson</td><td>CA</td><td>61.2935461663849</td><td>84.06623188970703</td><td>97.90920460781855</td><td>64</td></tr><tr><td>10</td><td>93</td><td>40872</td><td>35-45</td><td>M</td><td>Los Angeles</td><td>CA</td><td>56.30002261623926</td><td>114.19709480408216</td><td>149.01681342604203</td><td>256</td></tr><tr><td>10</td><td>319</td><td>34740</td><td>25-35</td><td>M</td><td>Santa Monica</td><td>CA</td><td>64.0610237063677</td><td>118.60556936009979</td><td>157.78960442289807</td><td>243</td></tr><tr><td>13</td><td>3</td><td>43104</td><td>45-55</td><td>F</td><td>Long Beach</td><td>CA</td><td>76.27838862371735</td><td>107.99528974128064</td><td>144.3507458165889</td><td>333</td></tr><tr><td>35</td><td>174</td><td>27306</td><td>55-65</td><td>F</td><td>Edwards</td><td>CA</td><td>68.50143158890829</td><td>90.9597633275273</td><td>130.43088939163587</td><td>358</td></tr><tr><td>18</td><td>487</td><td>14232</td><td>35-45</td><td>M</td><td>North Hollywood</td><td>CA</td><td>75.477955601599</td><td>96.46158296973003</td><td>128.10411564223133</td><td>129</td></tr><tr><td>1</td><td>56</td><td>37012</td><td>95+</td><td>M</td><td>Torrance</td><td>CA</td><td>51.21193883454026</td><td>76.10179850421733</td><td>113.42256961244996</td><td>409</td></tr><tr><td>27</td><td>305</td><td>29213</td><td>95+</td><td>F</td><td>North Hollywood</td><td>CA</td><td>55.764492065796944</td><td>87.34860751358602</td><td>113.69300268327184</td><td>308</td></tr><tr><td>24</td><td>7</td><td>28588</td><td>35-45</td><td>M</td><td>Arcadia</td><td>CA</td><td>86.79649956680105</td><td>136.36704625258028</td><td>168.72168469775733</td><td>52</td></tr><tr><td>31</td><td>95</td><td>40872</td><td>35-45</td><td>M</td><td>Los Angeles</td><td>CA</td><td>75.09802889864419</td><td>123.6009131158306</td><td>162.84801260836937</td><td>256</td></tr><tr><td>32</td><td>165</td><td>24018</td><td>75-85</td><td>F</td><td>Beverly Hills</td><td>CA</td><td>62.3737115836115</td><td>103.20951352688544</td><td>130.03655518615568</td><td>372</td></tr><tr><td>23</td><td>9</td><td>43052</td><td>75-85</td><td>F</td><td>Beverly Hills</td><td>CA</td><td>61.22370396583501</td><td>82.28869955283895</td><td>116.90026379293772</td><td>397</td></tr><tr><td>38</td><td>281</td><td>36644</td><td>75-85</td><td>M</td><td>Altadena</td><td>CA</td><td>56.26093483599173</td><td>78.72684738065195</td><td>114.48975394031653</td><td>269</td></tr><tr><td>33</td><td>6</td><td>19787</td><td>25-35</td><td>M</td><td>Northridge</td><td>CA</td><td>59.54274401916663</td><td>133.86571606888612</td><td>162.8432561498512</td><td>282</td></tr><tr><td>49</td><td>305</td><td>31362</td><td>18-25</td><td>F</td><td>Los Angeles</td><td>CA</td><td>88.04116341492343</td><td>112.39638930506007</td><td>154.63137544566908</td><td>90</td></tr><tr><td>30</td><td>415</td><td>35728</td><td>55-65</td><td>F</td><td>Montebello</td><td>CA</td><td>71.78674648227273</td><td>103.08913108457303</td><td>129.88723670439578</td><td>474</td></tr><tr><td>41</td><td>2</td><td>42643</td><td>65-75</td><td>F</td><td>Los Angeles</td><td>CA</td><td>66.57472682528356</td><td>78.6744181663135</td><td>100.3573207949603</td><td>154</td></tr><tr><td>26</td><td>4</td><td>49835</td><td>85-95</td><td>M</td><td>Alham ...

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %%
DA.cleanup()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dropping the database &#34;dbacademy_odl_user_771624_databrickslabs_com_adewd_5_2&#34;
# Removing the working directory &#34;dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/5.2&#34;
# Validating datasets...(1 seconds)
# </div>

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
