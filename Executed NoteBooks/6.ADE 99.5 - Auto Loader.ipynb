# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Ingest Data with Auto Loader
#
# Databricks Auto Loader is the recommended method for streaming raw data from cloud object storage. Auto Loader provides efficient, incremental, idempotent processing of data files from cloud object storage locations. Several enhancements to this ingestion method make it greatly preferred to directly streaming from the file source using open source Structured Streaming APIs.
#
# For small datasets, the default **directory listing** execution mode will provide provide exceptional performance and cost savings. As the size of your data scales, the preferred execution method is **file notification**, which requires configuring a connection to your storage queue service and event notification, which will allow Databricks to idempotently track and process all files as they arrive in your storage account.
#
# In this notebook, we'll go through the basic configuration to ingest the log files for device MAC addresses from partner gyms.
#
# <img src="https://files.training.databricks.com/images/ade/ADE_arch_gym_logs.png" width="60%" />
#
# ## Learning Objectives
# By the end of this lesson, students will be able to:
# - Use Auto Loader to incrementally, idempotently load data from object storage to Delta Tables
# - Locate operation metrics using the **`DESCRIBE HISTORY`** command

# %% [markdown]
# ## File Detection Modes
#
# ![](https://files.training.databricks.com/images/autoloader-detection-modes.png)
#
# Auto Loader can be configured with two different file detection modes. While directory listing mode is the default and works well for small datasets and testing, file notification mode is preferred for large scale production applications.
#
# | **Directory Listing Mode** | **File Notification Mode** |
# | --- | --- |
# | Default mode | Requires some security permissions to other cloud services |
# | Easily stream files from object storage without configuration | Uses cloud storage queue service and event notifications to track files |
# | Creates file queue through parallel listing of input directory | Configurations handled automatically by Databricks |
# | Good for smaller source directories | Scales well as data grows |
#
# **NOTE**: Only directory listing mode will be shown in this notebook.

# %% [markdown]
# ## Schema Inference and Evolution
# Auto Loader has advanced support for working with data sources with unknown or changing schemas, including the ability to:
# * Identify schema on stream initialization
# * Auto-detect changes and evolve schema to capture new fields
# * Add type hints for enforcement when schema is known
# * Rescue data that does not meet expectations
#
# Full documentation of this functionality is available <a href="https://docs.databricks.com/spark/latest/structured-streaming/auto-loader-schema.html" target="_blank">here</a>.

# %% [markdown]
# ## Setup
#
# The notebook below defines a function to allow us to manually trigger new data landing in our source container.
#
# This will allow us to see Auto Loader in action.

# %%
# %run ../Includes/Classroom-Setup-1.5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Creating the database &#34;dbacademy_odl_user_771624_databrickslabs_com_adewd_1_5&#34;
# Creating gym_mac_logs dataset...(5 seconds)
#
# Predefined Paths:
#   DA.paths.working_dir:       dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5
#   DA.paths.user_db:           dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/1_5.db
#   DA.paths.checkpoints:       dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/_checkpoints
#   DA.paths.gym_mac_logs_json: dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json
#
# Predefined tables in dbacademy_odl_user_771624_databrickslabs_com_adewd_1_5:
#   -none-
#
# Validating datasets...(0 seconds)
#
# Setup completed in 7 seconds
# </div>

# %% [markdown]
# Our source directory contains a number of JSON files representing about a week of data.

# %%
files = dbutils.fs.ls(DA.paths.gym_mac_logs_json)
display(files)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_1.json</td><td>20191201_1.json</td><td>98</td><td>1666781126000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_2.json</td><td>20191201_2.json</td><td>292</td><td>1666781126000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_3.json</td><td>20191201_3.json</td><td>195</td><td>1666781126000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_4.json</td><td>20191201_4.json</td><td>195</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_5.json</td><td>20191201_5.json</td><td>486</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191201_6.json</td><td>20191201_6.json</td><td>195</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191202_2.json</td><td>20191202_2.json</td><td>389</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191202_3.json</td><td>20191202_3.json</td><td>195</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191202_4.json</td><td>20191202_4.json</td><td>389</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191202_5.json</td><td>20191202_5.json</td><td>389</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191202_6.json</td><td>20191202_6.json</td><td>98</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_1.json</td><td>20191203_1.json</td><td>98</td><td>1666781127000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_2.json</td><td>20191203_2.json</td><td>389</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_3.json</td><td>20191203_3.json</td><td>389</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_4.json</td><td>20191203_4.json</td><td>195</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_5.json</td><td>20191203_5.json</td><td>680</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191203_6.json</td><td>20191203_6.json</td><td>98</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191204_1.json</td><td>20191204_1.json</td><td>98</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191204_2.json</td><td>20191204_2.json</td><td>389</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191204_3.json</td><td>20191204_3.json</td><td>98</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191204_4.json</td><td>20191204_4.json</td><td>292</td><td>1666781128000</td></tr><tr><td>dbfs:/user/odl_user_771624@databrickslabs.com/dbacademy/adewd/1.5/gym_mac_logs.json/20191204_5.json</td><td>20191204_5.json< ...

# %% [markdown]
# ## Using CloudFiles
#
# Configuring Auto Loader requires using the **`cloudFiles`** format.
#
# The syntax for this format differs only slightly from a standard streaming read.
#
# To configure we need to:
# 1. Specify the format as **`cloudFiles`**
# 2. Specify the file format via **`cloudFiles.format`** as **`json`**
# 3. Provide the location that Auto Loader will store the inferred schema via **`cloudFiles.schemaLocation`**
# 4. Optionally configure Auto Loader to use cloud notifications via **`cloudFiles.useNotifications`**<br/>
# as opposed to listing the target directory.
#
# **Note:** The cloud-notifications feature does require additonal cloud configuration.
#
# See the <a href="https://docs.databricks.com/spark/latest/structured-streaming/auto-loader.html#configuration" target="_blank">Auto-Loader documentation</a> for more information.

# %%
def load_gym_logs():
    query = (spark.readStream
                  .format("cloudFiles")
                  .option("cloudFiles.format", "json")
                  .option("cloudFiles.schemaLocation", f"{DA.paths.checkpoints}/gym_mac_logs_schema")
                  # .option("cloudFiles.useNotifications","true") # Set this option for file notification mode
                  .load(DA.paths.gym_mac_logs_json)
                  .writeStream
                  .format("delta")
                  .option("checkpointLocation", f"{DA.paths.checkpoints}/gym_mac_logs")
                  .trigger(availableNow=True)
                  .table("gym_mac_logs"))
    
    query.awaitTermination()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Note that we're using **trigger-available-now** logic for batch execution.  trigger-available-now is very similar to **trigger-once** but can run
# multiple batches until all available data is consumed instead of one big batch, and is introduced in <a href="https://spark.apache.org/releases/spark-release-3-3-0.html" target="_blank">Spark 3.3.0</a> and <a href="https://docs.databricks.com/release-notes/runtime/10.4.html" target="_blank">Databricks Runtime 10.4 LTS</a>. While we may not have the latency requirements of a Structured Streaming workload, Auto Loader prevents any CDC on our file source, allowing us to simply trigger a cron job daily to process all new data that's arrived.

# %%
load_gym_logs()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# As always, each batch of newly processed data will create a new version of our table.

# %%
# %sql 
DESCRIBE HISTORY gym_mac_logs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2022-10-26T10:47:22.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> cea2994a-322c-430a-b41c-4e5556a76214, epochId -> 0)</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 155, numOutputBytes -> 10867, numAddedFiles -> 4)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>0</td><td>2022-10-26T10:47:17.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>CREATE TABLE</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr></tbody></table></div>

# %% [markdown]
# The helper method below will load an additional day of data.

# %%
DA.gym_mac_stream.load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Loading gym_mac_logs for day #10...(1 seconds, 6 files)
# </div>

# %% [markdown]
# CloudFiles will ignore previously processed data; only those newly written files will be processed.

# %%
load_gym_logs()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql DESCRIBE HISTORY gym_mac_logs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2022-10-26T10:50:31.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> cea2994a-322c-430a-b41c-4e5556a76214, epochId -> 1)</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 23, numOutputBytes -> 5898, numAddedFiles -> 3)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>1</td><td>2022-10-26T10:47:22.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> cea2994a-322c-430a-b41c-4e5556a76214, epochId -> 0)</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 155, numOutputBytes -> 10867, numAddedFiles -> 4)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>0</td><td>2022-10-26T10:47:17.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>CREATE TABLE</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr></tbody></table></div>

# %% [markdown]
# Run the cell below to process the remainder of the data provided.

# %%
DA.gym_mac_stream.load(continuous=True)
load_gym_logs()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Loading all gym_mac_log files...(4 seconds, 32 files)
# </div>

# %%
# %sql DESCRIBE HISTORY gym_mac_logs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>3</td><td>2022-10-26T10:51:03.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> cea2994a-322c-430a-b41c-4e5556a76214, epochId -> 2)</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows -> 136, numOutputBytes -> 10890, numAddedFiles -> 4)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>2</td><td>2022-10-26T10:50:31.000+0000</td><td>8453215174696142</td><td>odl_user_771624@databrickslabs.com</td><td>STREAMING UPDATE</td><td>Map(outputMode -> Append, queryId -> cea2994a-322c-430a-b41c-4e5556a76214, epochId -> 1)</td><td>null</td><td>List(4382774100892078)</td><td>1024-143331-6vol2yy0</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numRemovedFiles -> 0, numOutputRows ->